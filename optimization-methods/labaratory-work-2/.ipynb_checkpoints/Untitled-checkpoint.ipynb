# %%
import pandas as pd

class Item:
    def __init__(self, name, weight, value):
        self.name = name
        self.weight = weight
        self.value = value
        self.ratio = value / weight

def get_bound(current_w, current_v, index, n, W, items):
    """Вычисляет верхнюю границу (Bound) ценности"""
    if current_w >= W:
        return 0
    
    v_bound = current_v
    total_w = current_w
    j = index
    
    while j < n and total_w + items[j].weight <= W:
        total_w += items[j].weight
        v_bound += items[j].value
        j += 1
    
    if j < n:
        v_bound += (W - total_w) * items[j].ratio
        
    return v_bound

def solve_and_print(W, weights, values, names):
    n = len(weights)
    items = [Item(names[i], weights[i], values[i]) for i in range(n)]
    # Сортировка по удельной ценности для эффективности
    items.sort(key=lambda x: x.ratio, reverse=True)
    
    max_v = 0
    solutions = []

    print(f"🌳 ДЕРЕВО РЕШЕНИЙ (W={W})")
    print("Формат узла: [Предмет] Статус -> (Вес, Ценность) | Bound")
    print("-" * 60)

    def branch(level, cur_w, cur_v, path, prefix="", is_left=True):
        nonlocal max_v, solutions
        
        # Визуализация ветвления
        connector = "├── " if is_left else "└── "
        node_name = items[level].name if level < n else "END"
        
        # Считаем границу для текущего узла
        bound = get_bound(cur_w, cur_v, level, n, W, items)
        
        # Вывод текущего узла
        print(f"{prefix}{connector}{node_name}: (w:{cur_w}, v:{cur_v}) | B:{bound:.1f}", end="")
        
        # Проверка на отсечение
        if bound <= max_v and max_v > 0:
            print(" ❌ (Отсечено: Bound <= MaxV)")
            return
        
        if level == n:
            if cur_v > max_v:
                max_v = cur_v
                solutions = [path]
                print(" ⭐ НОВЫЙ МАКСИМУМ!")
            elif cur_v == max_v and max_v > 0:
                solutions.append(path)
                print(" 💎 Дубликат максимума")
            else:
                print(" ⏹️ Лист")
            return
        
        print("") # Переход на новую строку для дочерних узлов
        new_prefix = prefix + ("│   " if is_left else "    ")
        
        # 1. Ветка "Взять предмет"
        if cur_w + items[level].weight <= W:
            branch(level + 1, 
                   cur_w + items[level].weight, 
                   cur_v + items[level].value, 
                   path + [items[level].name], 
                   new_prefix, True)
        else:
            print(f"{new_prefix}├── {items[level].name}: Не влезает")
            
        # 2. Ветка "Пропустить предмет"
        branch(level + 1, cur_w, cur_v, path, new_prefix, False)

    branch(0, 0, 0, [])
    
    print("-" * 60)
    if not solutions:
        print("ИТОГ: Решений нет.")
    else:
        print(f"ОПТИМАЛЬНАЯ ЦЕННОСТЬ: {max_v}")
        print("ЛУЧШИЕ НАБОРЫ:", " ИЛИ ".join([str(s) for s in solutions]))

# Тестовые данные
W_limit = 10
w = [2, 5, 10, 5]
v = [20, 30, 50, 10]
n = ["A", "B", "C", "D"]

solve_and_print(W_limit, w, v, n)
# Out:
# 🌳 ДЕРЕВО РЕШЕНИЙ (W=10)
# Формат узла: [Предмет] Статус -> (Вес, Ценность) | Bound
# ------------------------------------------------------------
# ├── A: (w:0, v:0) | B:65.0
# │   ├── B: (w:2, v:20) | B:65.0
# │   │   ├── C: (w:7, v:50) | B:65.0
# │   │   │   ├── C: Не влезает
# │   │   │   └── D: (w:7, v:50) | B:56.0
# │   │   │       ├── D: Не влезает
# │   │   │       └── END: (w:7, v:50) | B:50.0 ⭐ НОВЫЙ МАКСИМУМ!
# │   │   └── C: (w:2, v:20) | B:60.0
# │   │       ├── C: Не влезает
# │   │       └── D: (w:2, v:20) | B:30.0 ❌ (Отсечено: Bound <= MaxV)
# │   └── B: (w:0, v:0) | B:55.0
# │       ├── C: (w:5, v:30) | B:55.0
# │       │   ├── C: Не влезает
# │       │   └── D: (w:5, v:30) | B:40.0 ❌ (Отсечено: Bound <= MaxV)
# │       └── C: (w:0, v:0) | B:50.0 ❌ (Отсечено: Bound <= MaxV)
# ------------------------------------------------------------
# ОПТИМАЛЬНАЯ ЦЕННОСТЬ: 50
# ЛУЧШИЕ НАБОРЫ: ['A', 'B']
